# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect

# %%
 csv_file = "data-csv/tournaments.csv"
tournaments = pd.read_csv(csv_file)
tournaments.head()
# Out:
#    key_id tournament_id      tournament_name  year  start_date    end_date  \
# 0       1       WC-1930  1930 FIFA World Cup  1930  1930-07-13  1930-07-30
# 1       2       WC-1934  1934 FIFA World Cup  1934  1934-05-27  1934-06-10
# 2       3       WC-1938  1938 FIFA World Cup  1938  1938-06-04  1938-06-19
# 3       4       WC-1950  1950 FIFA World Cup  1950  1950-06-24  1950-07-16
# 4       5       WC-1954  1954 FIFA World Cup  1954  1954-06-16  1954-07-04
#
#   host_country        winner  host_won  count_teams  group_stage  \
# 0      Uruguay       Uruguay         1           13            1
# 1        Italy         Italy         1           16            0
# 2       France         Italy         0           15            0
# 3       Brazil       Uruguay         0           13            1
# 4  Switzerland  West Germany         0           16            1
#
#    second_group_stage  final_round  round_of_16  quarter_finals  semi_finals  \
# 0                   0            0            0               0            1
# 1                   0            0            1               1            1
# 2                   0            0            1               1            1
# 3                   0            1            0               0            0
# 4                   0            0            0               1            1
#
#    third_place_match  final
# 0                  0      1
# 1                  1      1
# 2                  1      1
# 3                  0      0
# 4                  1      1

# %%
new_tournaments = tournaments[['tournament_id', 'tournament_name','year', 'host_country','winner','host_won','count_teams','group_stage','second_group_stage','final_round','round_of_16','quarter_finals','semi_finals','third_place_match','final']].copy()

new_tournaments.head()
# Out:
#   tournament_id      tournament_name  year host_country        winner  \
# 0       WC-1930  1930 FIFA World Cup  1930      Uruguay       Uruguay
# 1       WC-1934  1934 FIFA World Cup  1934        Italy         Italy
# 2       WC-1938  1938 FIFA World Cup  1938       France         Italy
# 3       WC-1950  1950 FIFA World Cup  1950       Brazil       Uruguay
# 4       WC-1954  1954 FIFA World Cup  1954  Switzerland  West Germany
#
#    host_won  count_teams  group_stage  second_group_stage  final_round  \
# 0         1           13            1                   0            0
# 1         1           16            0                   0            0
# 2         0           15            0                   0            0
# 3         0           13            1                   0            1
# 4         0           16            1                   0            0
#
#    round_of_16  quarter_finals  semi_finals  third_place_match  final
# 0            0               0            1                  0      1
# 1            1               1            1                  1      1
# 2            1               1            1                  1      1
# 3            0               0            0                  0      0
# 4            0               1            1                  1      1
