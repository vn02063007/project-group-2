# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect

# %%
 csv_file = "data-csv/player_appearances.csv"
player_appearances = pd.read_csv(csv_file)
player_appearances.head()
# Out:
#    key_id tournament_id      tournament_name   match_id  \
# 0       1       WC-1970  1970 FIFA World Cup  M-1970-01
# 1       2       WC-1970  1970 FIFA World Cup  M-1970-01
# 2       3       WC-1970  1970 FIFA World Cup  M-1970-01
# 3       4       WC-1970  1970 FIFA World Cup  M-1970-01
# 4       5       WC-1970  1970 FIFA World Cup  M-1970-01
#
#               match_name  match_date   stage_name group_name team_id  \
# 0  Mexico v Soviet Union  1970-05-31  group stage    Group 1    T-44
# 1  Mexico v Soviet Union  1970-05-31  group stage    Group 1    T-44
# 2  Mexico v Soviet Union  1970-05-31  group stage    Group 1    T-44
# 3  Mexico v Soviet Union  1970-05-31  group stage    Group 1    T-44
# 4  Mexico v Soviet Union  1970-05-31  group stage    Group 1    T-44
#
#   team_name  ... away_team  player_id  family_name     given_name  \
# 0    Mexico  ...         0    P-02951     Calderón        Ignacio
# 1    Mexico  ...         0    P-09033         Peña        Gustavo
# ...

# %%
new_player_appearances = player_appearances[['player_id', 'tournament_id','match_id', 'team_id','starter','substitute','captain']].copy()

new_player_appearances.head()
# Out:
#   player_id tournament_id   match_id team_id  starter  substitute  captain
# 0   P-02951       WC-1970  M-1970-01    T-44        1           0        0
# 1   P-09033       WC-1970  M-1970-01    T-44        1           0        1
# 2   P-02770       WC-1970  M-1970-01    T-44        1           0        0
# 3   P-04709       WC-1970  M-1970-01    T-44        1           0        0
# 4   P-01956       WC-1970  M-1970-01    T-44        1           0        0
